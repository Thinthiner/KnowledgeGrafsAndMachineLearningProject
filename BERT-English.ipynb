# %%
# Standard python modules
from functools import lru_cache
from os.path import expanduser, join

# Extra python modules
from bert_serving.client import BertClient
from bpemb import BPEmb
from IPython.display import display
#from gensim.models.fasttext import FastText
import numpy as np
from numpy.linalg import norm
import pandas as pd
import requests

import json
import csv
import itertools
from sklearn.decomposition import PCA
from sklearn.metrics.pairwise import cosine_similarity

# %%
# INSTALL
#pip install bert-serving-server  # server
#pip install bert-serving-client  # client, independent of `bert-serving-server`

# %%
# The data we will work on is from the `dasem` toolbox available at https://github.com/fnielsen/dasem
# Only the four_words_2.csv file is necessary here, - not the rest of `dasem`.
#filename_four_words = expanduser(r'/home/s165541/Bert/four_words_english.csv')
#four_words = pd.read_csv(filename_four_words)

wordToSimilarWordsMap = {}
with open(r'C:/Users/thina/Documents/Matematik_og_teknologi/Advanced Machine Learning/FastText/four_words_english.json', "r") as read_file:
    data = json.load(read_file)
    for wordObj in data:
        wordToSimilarWordsMap[wordObj['word']] = wordObj['lexeme']

four_words_csv = []
with open(r'C:/Users/thina/Documents/Matematik_og_teknologi/Advanced Machine Learning/FastText/four_words_english.csv', newline='') as csvfile:
    data_csv = csv.reader(csvfile, delimiter='.', quotechar='|')
    for row in data_csv:
        words = row[0].split(",")
        words = [word.strip() for word in words]
        four_words_csv.append(words)  

four_words_csv.pop(0)
# The fasttext model is available from https://fasttext.cc/docs/en/crawl-vectors.html
#filename_fasttext_model = expanduser(join('~', 'data', 'fasttext', 'cc.da.300.bin'))

# multi_cased_L-12_H-768_A-12 may be be downloaded from
# https://storage.googleapis.com/bert_models/2018_11_23/multi_cased_L-12_H-768_A-12.zip
#https://storage.googleapis.com/bert_models/2019_05_30/wwm_uncased_L-24_H-1024_A-16.zip

#import zipfile
#with zipfile.ZipFile('/home/s165541/Bert/multi_cased_L-12_H-768_A-12.zip', 'r') as zip_ref:
#    zip_ref.extractall('/home/s165541/Bert')


# BPEmb are downloaded automatically
# Out:
# ['word1', 'word2', 'word3', 'word4']

# %%
# Run in terminal 
# python start-bert-as-service.py -model_dir ./wwm_uncased_L-24_H-1024_A-16 -num_worker=1

# %%
bc = BertClient(ip='localhost')

# %%
print(bc.encode(wordToSimilarWordsMap['train']).shape)
print(four_words_csv[82])
print(wordToSimilarWordsMap[four_words_csv[82][1]])
print(four_words_csv[85][1].split())
print(wordToSimilarWordsMap[four_words_csv[85][0]])
# Out:
# (4, 1024)
# ['white', 'black', 'red', 'apple']
# ['blackest', 'blacker', 'black', 'കറുപ്പ്']
# ['kitchen']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-eccd4e5ff9c9> in <module>
#       3 print(wordToSimilarWordsMap[four_words_csv[82][1]])
#       4 print(four_words_csv[85][1].split())
# ----> 5 print(wordToSimilarWordsMap[four_words_csv[85][0]])
#
# KeyError: 'dining room'

# %% [markdown]
# # Knowledge Graph

# %%
corrcoef_outliers, cov_outliers, dot_outliers, cosine_outliers, svd_outliers, pca_outliers = [], [], [], [], [], []
for i in range(len(four_words_csv)): 
    vectors = np.zeros((4,1024))
    for j in range(4): 
        word = four_words_csv[i][j]
        if len(word.split()) is 1: 
            vectors[j,:] = np.mean(bc.encode(wordToSimilarWordsMap[word]), axis=0)
        elif len(word.split()) is 2: 
            word = word.split()
            vectors[j,:] = np.mean(bc.encode(wordToSimilarWordsMap[word[0]])+bc.encode(wordToSimilarWordsMap[word[1]]), axis=0)
        
    R = np.corrcoef(vectors)
    indices = np.argsort(R.sum(axis=0))
    outlier = four_words_csv[i][indices[0]]
    corrcoef_outliers.append(outlier)

    C = np.cov(vectors)
    indices = np.argsort(C.sum(axis=0))
    outlier = four_words_csv[i][indices[0]]
    cov_outliers.append(outlier)

    D = np.dot(vectors, vectors.T)
    indices = np.argsort(D.sum(axis=0))
    outlier = four_words_csv[i][indices[0]]
    dot_outliers.append(outlier)
    
    CO = np.dot(vectors, vectors.T)
    square_mag = np.diag(CO)
    inv_square_mag = 1 / square_mag
    inv_square_mag[np.isinf(inv_square_mag)] = 0
    inv_mag = np.sqrt(inv_square_mag)
    cosine = CO * inv_mag
    cosine = cosine.T * inv_mag
    indices = np.argsort(cosine.sum(axis=0))
    outlier = four_words_csv[i][indices[0]]
    cosine_outliers.append(outlier)
    
    
    vecs = np.transpose(vectors)
    MeanVector = np.mean(vecs, axis = 1)[:,np.newaxis]
    vecs = np.concatenate((vecs,MeanVector), axis = 1)
    
    # SVD
    U, s, Vh = np.linalg.svd(vecs,full_matrices=False)
    Dist = np.zeros(4)

    for j in range(4):
        Dist[j] = np.linalg.norm(U[4,0]-U[j,0])+np.linalg.norm(U[4,1]-U[j,1])
    outlier = four_words_csv[i][np.where(Dist == max(Dist))[0][0]]
    svd_outliers.append(outlier)
    
    
    # PCA
    pca_vecs = PCA(n_components=2, svd_solver = 'arpack')
    X_pca_vecs = pca_vecs.fit_transform(vecs) # Calculate PCA of vector

    Dist_pca_vecs = np.zeros(4) # Calculate distance 
    for j in range(4):
        Dist_pca_vecs[j] = np.linalg.norm(X_pca_vecs[4,0]-X_pca_vecs[j,0])+np.linalg.norm(X_pca_vecs[4,1]-X_pca_vecs[j,1])
    outlier = four_words_csv[i][np.where(Dist_pca_vecs == max(Dist_pca_vecs))[0][0]]
    pca_outliers.append(outlier)
    
    print('Progress', i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-1730c2730377> in <module>
#       5         word = four_words_csv[i][j]
#       6         if len(word.split()) is 1:
# ----> 7             vectors[j,:] = np.mean(bc.encode('similar to '+wordToSimilarWordsMap[word]), axis=0)
#       8         elif len(word.split()) is 2:
#       9             word = word.split()
#
# TypeError: must be str, not list

# %%
sum_corr = 0
for i in range(len(four_words_csv)):
    if four_words_csv[i][3] == corrcoef_outliers[i]:
        sum_corr += 1
    
sum_corr/len(four_words_csv)
# Out:
# 0.4262295081967213

# %%
sum_cov = 0
for i in range(len(four_words_csv)):
    if four_words_csv[i][3] == cov_outliers[i]:
        sum_cov += 1
    
sum_cov/len(four_words_csv)
# Out:
# 0.2786885245901639

# %%
sum_dot = 0
for i in range(len(four_words_csv)):
    if four_words_csv[i][3] == dot_outliers[i]:
        sum_dot += 1
    
sum_dot/len(four_words_csv)
# Out:
# 0.2786885245901639

# %%
sum_svd = 0
for i in range(len(four_words_csv)):
    if four_words_csv[i][3] == svd_outliers[i]:
        sum_svd += 1
    
sum_svd/len(four_words_csv)
# Out:
# 0.23497267759562843

# %%
sum_pca = 0
for i in range(len(four_words_csv)):
    if four_words_csv[i][3] == pca_outliers[i]:
        sum_pca += 1
    
sum_pca/len(four_words_csv)
# Out:
# 0.3333333333333333

# %%
sum_cosine = 0
for i in range(len(four_words_csv)):
    if four_words_csv[i][3] == cosine_outliers[i]:
        sum_cosine += 1
    
sum_cosine/len(four_words_csv)
# Out:
# 0.4262295081967213

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)
pd.DataFrame({'Word 1': np.array(four_words_csv)[:,0], 'Word 2': np.array(four_words_csv)[:,1], 'Word 3': np.array(four_words_csv)[:,2], 'Word 4': np.array(four_words_csv)[:,3], 'corrcoef': corrcoef_outliers, 
            'cov':cov_outliers, 'dot':dot_outliers,'SVD':svd_outliers, 'PCA':pca_outliers , 'cosine': cosine_outliers})

# %% [markdown]
# # Four Words

# %%
corrcoef_outliers, cov_outliers, dot_outliers, cosine_outliers, svd_outliers, pca_outliers = [], [], [], [], [], []
for i in range(len(four_words_csv)): 
    vectors = bc.encode(four_words_csv[i])
    
    R = np.corrcoef(vectors)
    indices = np.argsort(R.sum(axis=0))
    outlier = four_words_csv[i][indices[0]]
    corrcoef_outliers.append(outlier)

    C = np.cov(vectors)
    indices = np.argsort(C.sum(axis=0))
    outlier = four_words_csv[i][indices[0]]
    cov_outliers.append(outlier)

    D = np.dot(vectors, vectors.T)
    indices = np.argsort(D.sum(axis=0))
    outlier = four_words_csv[i][indices[0]]
    dot_outliers.append(outlier)
    
    CO = np.dot(vectors, vectors.T)
    square_mag = np.diag(CO)
    inv_square_mag = 1 / square_mag
    inv_square_mag[np.isinf(inv_square_mag)] = 0
    inv_mag = np.sqrt(inv_square_mag)
    cosine = CO * inv_mag
    cosine = cosine.T * inv_mag
    indices = np.argsort(cosine.sum(axis=0))
    outlier = four_words_csv[i][indices[0]]
    cosine_outliers.append(outlier)
    
    
    vecs = np.transpose(vectors)
    MeanVector = np.mean(vecs, axis = 1)[:,np.newaxis]
    vecs = np.concatenate((vecs,MeanVector), axis = 1)
    
    # SVD
    U, s, Vh = np.linalg.svd(vecs,full_matrices=False)
    Dist = np.zeros(4)

    for j in range(4):
        Dist[j] = np.linalg.norm(U[4,0]-U[j,0])+np.linalg.norm(U[4,1]-U[j,1])
    outlier = four_words_csv[i][np.where(Dist == max(Dist))[0][0]]
    svd_outliers.append(outlier)
    
    
    # PCA
    pca_vecs = PCA(n_components=2, svd_solver = 'arpack')
    X_pca_vecs = pca_vecs.fit_transform(vecs) # Calculate PCA of vector

    Dist_pca_vecs = np.zeros(4) # Calculate distance 
    for j in range(4):
        Dist_pca_vecs[j] = np.linalg.norm(X_pca_vecs[4,0]-X_pca_vecs[j,0])+np.linalg.norm(X_pca_vecs[4,1]-X_pca_vecs[j,1])
    outlier = four_words_csv[i][np.where(Dist_pca_vecs == max(Dist_pca_vecs))[0][0]]
    pca_outliers.append(outlier)
    
    print('Progress', i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-95e6cc74272f> in <module>
#       1 corrcoef_outliers, cov_outliers, dot_outliers, cosine_outliers, svd_outliers, pca_outliers = [], [], [], [], [], []
#       2 for i in range(len(four_words_csv)):
# ----> 3     vectors = bc.encode('similar to '+four_words_csv[i])[2:]
#       4
#       5     R = np.corrcoef(vectors)
#
# TypeError: must be str, not list

# %%
sum_corr = 0
for i in range(len(four_words_csv)):
    if four_words_csv[i][3] == corrcoef_outliers[i]:
        sum_corr += 1
    
print('Outlier detection using correlation coefficients', sum_corr/len(four_words_csv))

sum_cov = 0
for i in range(len(four_words_csv)):
    if four_words_csv[i][3] == cov_outliers[i]:
        sum_cov += 1
    
print('Outlier detection using covarians', sum_cov/len(four_words_csv))

sum_dot = 0
for i in range(len(four_words_csv)):
    if four_words_csv[i][3] == dot_outliers[i]:
        sum_dot += 1
    
print('Outlier detection using dot', sum_dot/len(four_words_csv))

sum_svd = 0
for i in range(len(four_words_csv)):
    if four_words_csv[i][3] == svd_outliers[i]:
        sum_svd += 1
    
print('Outlier detection using SVD', sum_svd/len(four_words_csv))

sum_pca = 0
for i in range(len(four_words_csv)):
    if four_words_csv[i][3] == pca_outliers[i]:
        sum_pca += 1
    
print('Outlier detection using PCA', sum_pca/len(four_words_csv))

sum_cosine = 0
for i in range(len(four_words_csv)):
    if four_words_csv[i][3] == cosine_outliers[i]:
        sum_cosine += 1
    
print('Outlier detection using cosine', sum_cosine/len(four_words_csv))
# Out:
# Outlier detection using correlation coefficients 0.40437158469945356
# Outlier detection using covarians 0.28415300546448086
# Outlier detection using dot 0.28415300546448086
# Outlier detection using SVD 0.24043715846994534
# Outlier detection using PCA 0.32786885245901637
# Outlier detection using cosine 0.40437158469945356

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)
pd.DataFrame({'Word 1': np.array(four_words_csv)[:,0], 'Word 2': np.array(four_words_csv)[:,1], 'Word 3': np.array(four_words_csv)[:,2], 'Word 4': np.array(four_words_csv)[:,3], 'corrcoef': corrcoef_outliers, 
            'cov':cov_outliers, 'dot':dot_outliers,'SVD':svd_outliers, 'PCA':pca_outliers , 'cosine': cosine_outliers})
# Out:
#           Word 1           Word 2        Word 3       Word 4     corrcoef  \
# 0          train              car         plane     exercise          car
# 1        brother           sister        father         iron       sister
# 2          stool            chair         couch         door         door
# 3           tree            grass          bush        clock        grass
# 4         poster            photo       picture       camera       poster
# 5         weight           height        length        meter       height
# 6           worm        earthworm     cockroach        tiger    cockroach
# 7        cereals             milk        butter        knife      cereals
# 8          lunch           dinner     breakfast      kitchen      kitchen
# 9     basketball         baseball      football     strategy     strategy
# 10           net             ball        racket       spider       racket
# 11         shirt         trousers        shorts       cheese       cheese
# 12           bag          luggage        pocket        money          bag
# 13           car            truck           van        plane          car
# 14        coffee              tea          soda        pasta        pasta
# 15          wind             rain          hail      poverty         hail
# 16          math       statistics   probability  environment         math
# 17    derivative         integral      division       course     division
# 18       student          teacher         class         room      student
# 19         brush              mop        duster       pencil       pencil
# 20           pen           pencil        marker       market       pencil
# 21        income             wage        salary     strategy       income
# 22         virus          illness      bacteria     medicine     bacteria
# 23           bar              pub         disco       office        disco
# 24        school       university     institute     building       school
# 25          book         notebook         sheet      stapler        sheet
# 26       caution           danger       problem    happiness      problem
# 27         knife              gun            ax         care          gun
# 28         price           ticket       receipt    expensive    expensive
# 29         lucky       optimistic   pessimistic       orange  pessimistic
# 30         green            black         brown          bag          bag
# 31    television            radio     newspaper     medicine        radio
# 32   engineering      mathematics       science     religion     religion
# 33     cathedral           church     monastery         shop    cathedral
# 34        friend            guest     companion        enemy       friend
# 35    philosophy       psychology       anatomy   government      anatomy
# 36          fear              joy      surprise          bed          bed
# 37     professor             book       meeting       pepper      meeting
# 38         Spain          Denmark        Turkey       nation       nation
# 39           son            child      daughter       family       family
# 40          data         computer       process         room     computer
# 41          game          console          play        hotel         game
# 42    volleyball        wrestling      baseball          bat          bat
# 43    ventilator  air-conditioner           fan     follower   ventilator
# 44         model         guidance          lead    aluminium        model
# 45        column             line           row         boat       column
# 46           rip              cut          tear          eye          cut
# 47          axis            pivot          axes        sword        pivot
# 48          bend            curve           bow        arrow         bend
# 49          good             well          fine          pay         fine
# 50          town             city       capital       letter       letter
# 51        bottle              jar           can       manage          can
# 52           pub           bistro           bar          rod       bistro
# 53      straight            right          left         went     straight
# 54          fish           salmon          bass       violin       salmon
# 55          down               up         right      correct         down
# 56        finger             hand          palm         pine       finger
# 57          hour             time         watch      display         time
# 58       Turkish          Spanish        Polish   fingernail   fingernail
# 59        attach           clinch           tie       bowtie       attach
# 60     wristband         necklace          ring         bang    wristband
# 61       dolphin            whale          seal        stamp         seal
# 62          park            place        square        green        place
# 63          word         sentence        letter         four         four
# 64        gossip          chatter      chitchat        empty     chitchat
# 65   information     intelligence     knowledge        dirty        dirty
# 66        notice        recognize        detect         hard       detect
# 67      thoughts           belief       concern     keyboard     thoughts
# 68          goal              aim       purpose     continue          aim
# 69           eye             brow       eyelash          bed          eye
# 70         humor              fun          joke     counting         joke
# 71          test       evaluation          exam        train        train
# 72         essay          article         paper        water        essay
# 73   environment          habitat  surroundings        judge        judge
# 74           zoo           animal        circus         ring       circus
# 75      estimate         forecast       predict         chew         chew
# 76        coffin             dead        buried        cheek        cheek
# 77       extinct       extinguish       abolish         fork      extinct
# 78     telephone            radio    television          eat        radio
# 79         pause             halt        freeze        shirt        pause
# 80          hurt        suffering    discomfort      running      running
# 81       citizen            local        native        guide       native
# 82         white            black           red        apple        apple
# 83        pencil           eraser         ruler         baby       pencil
# 84        square           circle      triangle     trousers     trousers
# 85   dining room          kitchen      bathroom        green  dining room
# 86         skirt            dress        jacket          pen          pen
# 87         apple             pear    strawberry        phone        phone
# 88           leg             head           arm        glass        glass
# 89         grape           orange     raspberry       potato       orange
# 90      climbing         swimming       cycling         face     swimming
# 91        eleven           twelve         three          May          May
# 92      football           tennis    basketball        water        water
# 93          rose            daisy          lily     computer     computer
# 94        market           bakery       butcher        bread      butcher
# 95          milk              tea        coffee         pink         pink
# 96           bus            train         plane        three        three
# 97       wedding            groom         bride     spinster        groom
# 98           hot              big         heavy          sad          hot
# 99          give             sing          walk           go         sing
# 100      careful        beautiful         awful        write      careful
# 101         none         somebody           few         that         that
# 102           on               in            at         then         then
# 103      believe          receive         siege       friend      receive
# 104          row           column          cell         boat       column
# 105         wave             lake         ocean     greeting     greeting
# 106        eagle              bat      kangaroo   volleyball     kangaroo
# 107         drum           guitar          bass        shark         drum
# 108         back             head           leg      forward      forward
# 109       summer             fall        spring         jump         jump
# 110       desert           forest      mountain      starter       forest
# 111       letter           number     character         poem       number
# 112        right          forward          left      correct         left
# 113         ring         necklace         watch      calling      calling
# 114          tie           blazer         shirt         knob         knob
# 115        train         training           gym       flower       flower
# 116        train              car           bus          gym          gym
# 117          run          running           ran        house        house
# 118    beautiful             ugly          nice      trailer         nice
# 119       butter            bread          milk    butterfly       butter
# 120        sleep         sleeping        sleepy       Tarzan       Tarzan
# 121          arm              leg          hand         army         army
# 122         bear            carry          bore          dog        carry
# 123         sing             song         music        sting         sing
# 124      several             many          lots          few          few
# 125         sand           bikini           tan        grass          tan
# 126         game          gameboy          play          boy          boy
# 127     labrador        chihuahua           pug       banana          pug
# 128       mother           father      daughter          sun          sun
# 129          bus           banana     sunflower        ocean       banana
# 130          tan             tank      Tanzania          cup         tank
# 131    Tanqueray           Bombay        Gordon      student    Tanqueray
# 132          gun             dead           die         pony          gun
# 133        bacon             salt      pretzels        jelly     pretzels
# 134       yellow           cheese           sun        plant       cheese
# 135        woman              man          love        candy        woman
# 136         blue           orange        yellow        spoon        spoon
# 137         face             nose         smile     facebook     facebook
# 138     in front           behind         below          cow          cow
# 139        cloud           cloudy        clouds       cinema       cinema
# 140    sunflower         sunshine    sunglasses    challenge    challenge
# 141         rain         umbrella       thunder        happy        happy
# 142    chocolate            chips       cookies       dinner        chips
# 143         feel            smell           see          eye          eye
# 144      western          fiction      thriller      theater      theater
# 145         fear          concern        sorrow        opera        opera
# 146        mouth            teeth           eye          arm        teeth
# 147        death            grave       funeral          arm          arm
# 148     distress          sadness        sorrow        happy        happy
# 149     football           tennis      handball       summer       summer
# 150       summer           bikini          sand         snow       summer
# 151     magazine         brochure      notebook     computer     computer
# 152         gift             give        donate         take         take
# 153         good           better          best          bad         best
# 154   manipulate            mango           man         show        mango
# 155          cat            tiger        jaguar     elephant       jaguar
# 156   Copenhagen        Amsterdam       Beijing       Norway      Beijing
# 157    apartment            house       cottage         lion         lion
# 158       Lyngby    Frederiksberg   Klampenborg          bun       Lyngby
# 159          run            sleep         drink       bottle          run
# 160        table            chair           bed        study        chair
# 161        drink         drinking         drink         sand         sand
# 162          tea           coffee         cocoa       cancer       cancer
# 163        heart             lung        kidney     headache        heart
# 164      Denmark           Norway        Sweden      Germany      Denmark
# 165        sleep         sleeping         slept       school       school
# 166          fly           spider           ant         bird         bird
# 167       carrot           tomato      cucumber          car     cucumber
# 168          sun             rain       thunder        glass          sun
# 169          vin            vodka           gin        couch        vodka
# 170         blue           orange           red        horse        horse
# 171     computer          gameboy      Nintendo          cat      gameboy
# 172          bed           pillow         quilt       window       window
# 173       Sunday           Monday      Thursday          sun          sun
# 174       banana           orange         apple          run          run
# 175        pizza            pasta    mozzarella         show         show
# 176          run             walk         drive          cup          run
# 177     Facebook        Instagram       YouTube        sleep    Instagram
# 178         lamp              sun    flashlight        happy        happy
# 179          cat              dog         mouse          cry          cat
# 180          car              fly         train    butterfly          car
# 181        uncle             aunt        cousin         fear         fear
# 182          DTU               KU           ITU        plant        plant
#
#              cov          dot           SVD            PCA       cosine
# 0            car          car      exercise          plane          car
# 1         sister       sister        sister         sister       sister
# 2           door         door         couch          couch         door
# 3          grass        grass          bush          clock        grass
# 4         camera       camera       picture         camera       poster
# 5         height       height        length         length       height
# 6           worm         worm     cockroach      cockroach    cockroach
# 7        cereals      cereals        butter         butter      cereals
# 8        kitchen      kitchen       kitchen        kitchen      kitchen
# 9       football     football      baseball       football     strategy
# 10           net          net        racket         racket       racket
# 11        cheese       cheese        cheese         cheese       cheese
# 12           bag          bag        pocket         pocket          bag
# 13           van          van         truck            car          car
# 14         pasta        pasta          soda          pasta        pasta
# 15          hail         hail          hail           hail         hail
# 16          math         math   environment    probability         math
# 17      division     division      division         course     division
# 18       student      student          room          class      student
# 19        pencil       pencil        pencil            mop       pencil
# 20        pencil       pencil        market         market       pencil
# 21        income       income        salary         salary       income
# 22      bacteria     bacteria       illness        illness     bacteria
# 23         disco        disco        office         office        disco
# 24        school       school    university      institute       school
# 25         sheet        sheet       stapler        stapler        sheet
# 26       problem      problem     happiness      happiness      problem
# 27           gun          gun            ax             ax          gun
# 28     expensive    expensive       receipt        receipt    expensive
# 29   pessimistic  pessimistic        orange          lucky  pessimistic
# 30           bag          bag         black          green          bag
# 31         radio        radio         radio       medicine        radio
# 32      religion     religion   mathematics    mathematics     religion
# 33     cathedral    cathedral     monastery      monastery    cathedral
# 34        friend       friend        friend          enemy       friend
# 35    philosophy   philosophy    psychology     psychology      anatomy
# 36      surprise     surprise           joy            joy          bed
# 37       meeting      meeting       meeting        meeting      meeting
# 38        nation       nation        Turkey        Denmark       nation
# 39        family       family         child          child       family
# 40      computer     computer       process           room     computer
# 41          game         game          play           play         game
# 42           bat          bat      baseball       baseball          bat
# 43    ventilator   ventilator           fan            fan   ventilator
# 44         model        model         model          model        model
# 45        column       column          line           boat       column
# 46           cut          cut           rip            rip          cut
# 47         pivot        pivot          axes           axes        pivot
# 48          bend         bend          bend           bend         bend
# 49          fine         fine          good           good         fine
# 50       capital      capital          city           city       letter
# 51           can          can           jar         manage          can
# 52           bar          bar           bar            rod       bistro
# 53      straight     straight          left           left     straight
# 54        salmon       salmon        salmon         salmon       salmon
# 55          down         down         right          right         down
# 56        finger       finger          pine           pine       finger
# 57          time         time       display        display         time
# 58    fingernail   fingernail    fingernail        Turkish   fingernail
# 59        attach       attach        bowtie         bowtie       attach
# 60     wristband    wristband          ring           bang    wristband
# 61          seal         seal         whale          whale         seal
# 62          park         park          park           park        place
# 63          word         word          four       sentence         four
# 64        gossip       gossip      chitchat       chitchat     chitchat
# 65         dirty        dirty         dirty      knowledge        dirty
# 66        detect       detect          hard           hard       detect
# 67      thoughts     thoughts       concern       keyboard     thoughts
# 68           aim          aim       purpose       continue          aim
# 69          brow         brow       eyelash        eyelash          eye
# 70          joke         joke         humor          humor         joke
# 71          exam         exam    evaluation          train        train
# 72         essay        essay         paper          paper        essay
# 73         judge        judge  surroundings   surroundings        judge
# 74        circus       circus        animal         animal       circus
# 75          chew         chew      estimate       estimate         chew
# 76         cheek        cheek        buried           dead        cheek
# 77       extinct      extinct       abolish        abolish      extinct
# 78         radio        radio     telephone      telephone        radio
# 79         pause        pause          halt           halt        pause
# 80       running      running          hurt     discomfort      running
# 81        native       native        native          local       native
# 82         apple        apple         black          white        apple
# 83        pencil       pencil         ruler         eraser       pencil
# 84      trousers     trousers        square         square     trousers
# 85   dining room  dining room         green          green  dining room
# 86        jacket       jacket           pen            pen          pen
# 87         apple        apple         phone          phone        phone
# 88          head         head           arm            arm        glass
# 89        potato       potato        orange         orange       orange
# 90       cycling      cycling      swimming       swimming     swimming
# 91           May          May         three          three          May
# 92      football     football    basketball     basketball        water
# 93          rose         rose          lily           lily     computer
# 94        bakery       bakery       butcher         market      butcher
# 95          pink         pink          pink           pink         pink
# 96         three        three         plane          plane        three
# 97         bride        bride         bride          bride        groom
# 98           sad          sad           big            sad          hot
# 99          sing         sing          sing             go         sing
# 100      careful      careful       careful        careful      careful
# 101     somebody     somebody           few           none         that
# 102         then         then          then           then         then
# 103      receive      receive         siege          siege      receive
# 104       column       column          boat           boat       column
# 105     greeting     greeting          lake       greeting     greeting
# 106     kangaroo     kangaroo      kangaroo       kangaroo     kangaroo
# 107         drum         drum        guitar          shark         drum
# 108         head         head       forward            leg      forward
# 109       summer       summer        summer         summer         jump
# 110       forest       forest      mountain        starter       forest
# 111       number       number        letter         number       number
# 112         left         left          left           left         left
# 113      calling      calling       calling        calling      calling
# 114         knob         knob         shirt          shirt         knob
# 115     training     training           gym            gym       flower
# 116          car          car           gym          train          gym
# 117          run          run           ran            ran        house
# 118         ugly         ugly          ugly        trailer         nice
# 119       butter       butter          milk           milk       butter
# 120       sleepy       sleepy        sleepy         sleepy       Tarzan
# 121          arm          arm           leg           hand         army
# 122        carry        carry         carry          carry        carry
# 123         sing         sing         sting          sting         sing
# 124          few          few          many           many          few
# 125        grass        grass          sand          grass          tan
# 126          boy          boy       gameboy            boy          boy
# 127       banana       banana        banana         banana          pug
# 128     daughter     daughter           sun            sun          sun
# 129       banana       banana         ocean          ocean       banana
# 130         tank         tank      Tanzania       Tanzania         tank
# 131    Tanqueray    Tanqueray       student        student    Tanqueray
# 132          gun          gun           die           dead          gun
# 133        jelly        jelly         bacon       pretzels     pretzels
# 134       cheese       cheese         plant          plant       cheese
# 135        candy        candy         woman          woman        woman
# 136         blue         blue        yellow         yellow        spoon
# 137        smile        smile      facebook       facebook     facebook
# 138          cow          cow           cow          below          cow
# 139       clouds       clouds        cloudy         clouds       cinema
# 140    challenge    challenge     challenge      challenge    challenge
# 141        happy        happy      umbrella       umbrella        happy
# 142    chocolate    chocolate     chocolate         dinner        chips
# 143         feel         feel           eye            eye          eye
# 144      theater      theater      thriller       thriller      theater
# 145        opera        opera          fear           fear        opera
# 146        mouth        mouth         mouth            eye        teeth
# 147        death        death           arm            arm          arm
# 148        happy        happy       sadness        sadness        happy
# 149       summer       summer      football       football       summer
# 150       summer       summer          sand           sand       summer
# 151     magazine     magazine      computer       computer     computer
# 152         take         take        donate         donate         take
# 153         good         good           bad            bad         best
# 154        mango        mango         mango          mango        mango
# 155       jaguar       jaguar      elephant          tiger       jaguar
# 156    Amsterdam    Amsterdam       Beijing        Beijing      Beijing
# 157        house        house          lion           lion         lion
# 158       Lyngby       Lyngby        Lyngby  Frederiksberg       Lyngby
# 159          run          run         drink          drink          run
# 160        chair        chair         chair            bed        chair
# 161         sand         sand         drink          drink         sand
# 162       cancer       cancer         cocoa         cancer       cancer
# 163        heart        heart        kidney         kidney        heart
# 164      Germany      Germany        Sweden         Sweden      Denmark
# 165       school       school         slept          slept       school
# 166         bird         bird           ant            ant         bird
# 167     cucumber     cucumber      cucumber            car     cucumber
# 168         rain         rain         glass            sun          sun
# 169        vodka        vodka           vin            vin        vodka
# 170        horse        horse          blue          horse        horse
# 171      gameboy      gameboy      Nintendo        gameboy      gameboy
# 172        quilt        quilt        pillow         pillow       window
# 173       Monday       Monday      Thursday         Monday          sun
# 174          run          run         apple            run          run
# 175   mozzarella   mozzarella         pizza           show         show
# 176          run          run         drive          drive          run
# 177    Instagram    Instagram         sleep          sleep    Instagram
# 178        happy        happy          lamp           lamp        happy
# 179          cat          cat           dog            dog          cat
# 180          car          car         train          train          car
# 181         fear         fear        cousin           fear         fear
# 182           KU           KU           DTU            DTU        plant
