# %%
# Standard python modules
from functools import lru_cache
from os.path import expanduser, join

# Extra python modules
from bert_serving.client import BertClient
from bpemb import BPEmb
from IPython.display import display
#from gensim.models.fasttext import FastText
import numpy as np
from numpy.linalg import norm
import pandas as pd
import requests

import json
import csv
import itertools
from sklearn.decomposition import PCA
from sklearn.metrics.pairwise import cosine_similarity

# %%
# INSTALL
#pip install bert-serving-server  # server
#pip install bert-serving-client  # client, independent of `bert-serving-server`

# %%
# The data we will work on is from the `dasem` toolbox available at https://github.com/fnielsen/dasem
# Only the four_words_2.csv file is necessary here, - not the rest of `dasem`.
#filename_four_words = expanduser(r'/home/s165541/Bert/four_words_english.csv')
#four_words = pd.read_csv(filename_four_words)

wordToSimilarWordsMap = {}
with open(r'C:/Users/thina/Documents/Matematik_og_teknologi/Advanced Machine Learning/FastText/four_words_english.json', "r") as read_file:
    data = json.load(read_file)
    for wordObj in data:
        wordToSimilarWordsMap[wordObj['word']] = wordObj['lexeme']

four_words_csv = []
with open(r'C:/Users/thina/Documents/Matematik_og_teknologi/Advanced Machine Learning/FastText/four_words_english.csv', newline='') as csvfile:
    data_csv = csv.reader(csvfile, delimiter='.', quotechar='|')
    for row in data_csv:
        words = row[0].split(",")
        words = [word.strip() for word in words]
        four_words_csv.append(words)  

four_words_csv.pop(0)
# The fasttext model is available from https://fasttext.cc/docs/en/crawl-vectors.html
#filename_fasttext_model = expanduser(join('~', 'data', 'fasttext', 'cc.da.300.bin'))

# multi_cased_L-12_H-768_A-12 may be be downloaded from
# https://storage.googleapis.com/bert_models/2018_11_23/multi_cased_L-12_H-768_A-12.zip
#https://storage.googleapis.com/bert_models/2019_05_30/wwm_uncased_L-24_H-1024_A-16.zip

#import zipfile
#with zipfile.ZipFile('/home/s165541/Bert/multi_cased_L-12_H-768_A-12.zip', 'r') as zip_ref:
#    zip_ref.extractall('/home/s165541/Bert')


# BPEmb are downloaded automatically
# Out:
# ['word1', 'word2', 'word3', 'word4']

# %%
# Run in terminal 
# python start-bert-as-service.py -model_dir ./multi_cased_L-12_H-768_A-12 -num_worker=1

# %%
bc = BertClient(ip='localhost')

# %%
corrcoef_outliers, cov_outliers, dot_outliers, cosine_outliers, svd_outliers, pca_outliers = [], [], [], [], [], []
for i in range(len(four_words_csv)): 
    vectors = np.zeros((4,1024))
    for j in range(4): 
        word = four_words_csv[i][j]
        if len(word.split()) is 1: 
            vectors[j,:] = np.mean(bc.encode(['similarity '+word]), axis=0)
        elif len(word.split()) is 2: 
            word = word.split()
            vectors[j,:] = np.mean(bc.encode(['similarity '+word[0]])+bc.encode(['similarity '+word[1]]), axis=0)
        
    R = np.corrcoef(vectors)
    indices = np.argsort(R.sum(axis=0))
    outlier = four_words_csv[i][indices[0]]
    corrcoef_outliers.append(outlier)

    C = np.cov(vectors)
    indices = np.argsort(C.sum(axis=0))
    outlier = four_words_csv[i][indices[0]]
    cov_outliers.append(outlier)

    D = np.dot(vectors, vectors.T)
    indices = np.argsort(D.sum(axis=0))
    outlier = four_words_csv[i][indices[0]]
    dot_outliers.append(outlier)
    
    CO = np.dot(vectors, vectors.T)
    square_mag = np.diag(CO)
    inv_square_mag = 1 / square_mag
    inv_square_mag[np.isinf(inv_square_mag)] = 0
    inv_mag = np.sqrt(inv_square_mag)
    cosine = CO * inv_mag
    cosine = cosine.T * inv_mag
    indices = np.argsort(cosine.sum(axis=0))
    outlier = four_words_csv[i][indices[0]]
    cosine_outliers.append(outlier)
    
    
    vecs = np.transpose(vectors)
    MeanVector = np.mean(vecs, axis = 1)[:,np.newaxis]
    vecs = np.concatenate((vecs,MeanVector), axis = 1)
    
    # SVD
    U, s, Vh = np.linalg.svd(vecs,full_matrices=False)
    Dist = np.zeros(4)

    for j in range(4):
        Dist[j] = np.linalg.norm(U[4,0]-U[j,0])+np.linalg.norm(U[4,1]-U[j,1])
    outlier = four_words_csv[i][np.where(Dist == max(Dist))[0][0]]
    svd_outliers.append(outlier)
    
    
    # PCA
    pca_vecs = PCA(n_components=2, svd_solver = 'arpack')
    X_pca_vecs = pca_vecs.fit_transform(vecs) # Calculate PCA of vector

    Dist_pca_vecs = np.zeros(4) # Calculate distance 
    for j in range(4):
        Dist_pca_vecs[j] = np.linalg.norm(X_pca_vecs[4,0]-X_pca_vecs[j,0])+np.linalg.norm(X_pca_vecs[4,1]-X_pca_vecs[j,1])
    outlier = four_words_csv[i][np.where(Dist_pca_vecs == max(Dist_pca_vecs))[0][0]]
    pca_outliers.append(outlier)
    
    print('Progress', i)
# Out:
# Progress 0
# Progress 1
# Progress 2
# Progress 3
# Progress 4
# Progress 5
# Progress 6
# Progress 7
# Progress 8
# Progress 9
# Progress 10
# Progress 11
# Progress 12
# Progress 13
# Progress 14
# Progress 15
# Progress 16
# Progress 17
# Progress 18
# Progress 19
# Progress 20
# Progress 21
# Progress 22
# Progress 23
# Progress 24
# Progress 25
# Progress 26
# Progress 27
# Progress 28
# Progress 29
# Progress 30
# Progress 31
# Progress 32
# Progress 33
# Progress 34
# Progress 35
# Progress 36
# Progress 37
# Progress 38
# Progress 39
# Progress 40
# Progress 41
# Progress 42
# Progress 43
# Progress 44
# Progress 45
# Progress 46
# Progress 47
# Progress 48
# Progress 49
# Progress 50
# Progress 51
# Progress 52
# Progress 53
# Progress 54
# Progress 55
# Progress 56
# Progress 57
# Progress 58
# Progress 59
# Progress 60
# Progress 61
# Progress 62
# Progress 63
# Progress 64
# Progress 65
# Progress 66
# Progress 67
# Progress 68
# Progress 69
# Progress 70
# Progress 71
# Progress 72
# Progress 73
# Progress 74
# Progress 75
# Progress 76
# Progress 77
# Progress 78
# Progress 79
# Progress 80
# Progress 81
# Progress 82
# Progress 83
# Progress 84
# Progress 85
# Progress 86
# Progress 87
# Progress 88
# Progress 89
# Progress 90
# Progress 91
# Progress 92
# Progress 93
# Progress 94
# Progress 95
# Progress 96
# Progress 97
# Progress 98
# Progress 99
# Progress 100
# Progress 101
# Progress 102
# Progress 103
# Progress 104
# Progress 105
# Progress 106
# Progress 107
# Progress 108
# Progress 109
# Progress 110
# Progress 111
# Progress 112
# Progress 113
# Progress 114
# Progress 115
# Progress 116
# Progress 117
# Progress 118
# Progress 119
# Progress 120
# Progress 121
# Progress 122
# Progress 123
# Progress 124
# Progress 125
# Progress 126
# Progress 127
# Progress 128
# Progress 129
# Progress 130
# Progress 131
# Progress 132
# Progress 133
# Progress 134
# Progress 135
# Progress 136
# Progress 137
# Progress 138
# Progress 139
# Progress 140
# Progress 141
# Progress 142
# Progress 143
# Progress 144
# Progress 145
# Progress 146
# Progress 147
# Progress 148
# Progress 149
# Progress 150
# Progress 151
# Progress 152
# Progress 153
# Progress 154
# Progress 155
# Progress 156
# Progress 157
# Progress 158
# Progress 159
# Progress 160
# Progress 161
# Progress 162
# Progress 163
# Progress 164
# Progress 165
# Progress 166
# Progress 167
# Progress 168
# Progress 169
# Progress 170
# Progress 171
# Progress 172
# Progress 173
# Progress 174
# Progress 175
# Progress 176
# Progress 177
# Progress 178
# Progress 179
# Progress 180
# Progress 181
# Progress 182

# %%
sum_corr = 0
for i in range(len(four_words_csv)):
    if four_words_csv[i][3] == corrcoef_outliers[i]:
        sum_corr += 1
    
sum_corr/len(four_words_csv)
# Out:
# 0.6174863387978142

# %%
sum_cov = 0
for i in range(len(four_words_csv)):
    if four_words_csv[i][3] == cov_outliers[i]:
        sum_cov += 1
    
sum_cov/len(four_words_csv)
# Out:
# 0.3333333333333333

# %%
sum_dot = 0
for i in range(len(four_words_csv)):
    if four_words_csv[i][3] == dot_outliers[i]:
        sum_dot += 1
    
sum_dot/len(four_words_csv)
# Out:
# 0.3333333333333333

# %%
sum_svd = 0
for i in range(len(four_words_csv)):
    if four_words_csv[i][3] == svd_outliers[i]:
        sum_svd += 1
    
sum_svd/len(four_words_csv)
# Out:
# 0.08196721311475409

# %%
sum_pca = 0
for i in range(len(four_words_csv)):
    if four_words_csv[i][3] == pca_outliers[i]:
        sum_pca += 1
    
sum_pca/len(four_words_csv)
# Out:
# 0.0273224043715847

# %%
sum_cosine = 0
for i in range(len(four_words_csv)):
    if four_words_csv[i][3] == cosine_outliers[i]:
        sum_cosine += 1
    
sum_cosine/len(four_words_csv)
# Out:
# 0.6174863387978142

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)
pd.DataFrame({'Word 1': np.array(four_words_csv)[:,0], 'Word 2': np.array(four_words_csv)[:,1], 'Word 3': np.array(four_words_csv)[:,2], 'Word 4': np.array(four_words_csv)[:,3], 'corrcoef': corrcoef_outliers, 
            'cov':cov_outliers, 'dot':dot_outliers,'SVD':svd_outliers, 'PCA':pca_outliers , 'cosine': cosine_outliers})
# Out:
#           Word 1           Word 2        Word 3       Word 4     corrcoef  \
# 0          train              car         plane     exercise          car
# 1        brother           sister        father         iron         iron
# 2          stool            chair         couch         door         door
# 3           tree            grass          bush        clock        clock
# 4         poster            photo       picture       camera       camera
# 5         weight           height        length        meter        meter
# 6           worm        earthworm     cockroach        tiger    cockroach
# 7        cereals             milk        butter        knife        knife
# 8          lunch           dinner     breakfast      kitchen      kitchen
# 9     basketball         baseball      football     strategy     strategy
# 10           net             ball        racket       spider          net
# 11         shirt         trousers        shorts       cheese       cheese
# 12           bag          luggage        pocket        money        money
# 13           car            truck           van        plane        plane
# 14        coffee              tea          soda        pasta        pasta
# 15          wind             rain          hail      poverty      poverty
# 16          math       statistics   probability  environment  environment
# 17    derivative         integral      division       course     integral
# 18       student          teacher         class         room        class
# 19         brush              mop        duster       pencil       duster
# 20           pen           pencil        marker       market       market
# 21        income             wage        salary     strategy     strategy
# 22         virus          illness      bacteria     medicine        virus
# 23           bar              pub         disco       office        disco
# 24        school       university     institute     building     building
# 25          book         notebook         sheet      stapler      stapler
# 26       caution           danger       problem    happiness      problem
# 27         knife              gun            ax         care         care
# 28         price           ticket       receipt    expensive      receipt
# 29         lucky       optimistic   pessimistic       orange        lucky
# 30         green            black         brown          bag          bag
# 31    television            radio     newspaper     medicine     medicine
# 32   engineering      mathematics       science     religion     religion
# 33     cathedral           church     monastery         shop         shop
# 34        friend            guest     companion        enemy        guest
# 35    philosophy       psychology       anatomy   government   psychology
# 36          fear              joy      surprise          bed          bed
# 37     professor             book       meeting       pepper       pepper
# 38         Spain          Denmark        Turkey       nation       Turkey
# 39           son            child      daughter       family       family
# 40          data         computer       process         room         room
# 41          game          console          play        hotel      console
# 42    volleyball        wrestling      baseball          bat     baseball
# 43    ventilator  air-conditioner           fan     follower     follower
# 44         model         guidance          lead    aluminium    aluminium
# 45        column             line           row         boat         boat
# 46           rip              cut          tear          eye          eye
# 47          axis            pivot          axes        sword        sword
# 48          bend            curve           bow        arrow        arrow
# 49          good             well          fine          pay          pay
# 50          town             city       capital       letter      capital
# 51        bottle              jar           can       manage       manage
# 52           pub           bistro           bar          rod       bistro
# 53      straight            right          left         went     straight
# 54          fish           salmon          bass       violin         fish
# 55          down               up         right      correct      correct
# 56        finger             hand          palm         pine         pine
# 57          hour             time         watch      display        watch
# 58       Turkish          Spanish        Polish   fingernail      Spanish
# 59        attach           clinch           tie       bowtie       attach
# 60     wristband         necklace          ring         bang         bang
# 61       dolphin            whale          seal        stamp        stamp
# 62          park            place        square        green        green
# 63          word         sentence        letter         four         four
# 64        gossip          chatter      chitchat        empty        empty
# 65   information     intelligence     knowledge        dirty  information
# 66        notice        recognize        detect         hard         hard
# 67      thoughts           belief       concern     keyboard     keyboard
# 68          goal              aim       purpose     continue     continue
# 69           eye             brow       eyelash          bed         brow
# 70         humor              fun          joke     counting     counting
# 71          test       evaluation          exam        train        train
# 72         essay          article         paper        water      article
# 73   environment          habitat  surroundings        judge        judge
# 74           zoo           animal        circus         ring         ring
# 75      estimate         forecast       predict         chew         chew
# 76        coffin             dead        buried        cheek        cheek
# 77       extinct       extinguish       abolish         fork      extinct
# 78     telephone            radio    television          eat          eat
# 79         pause             halt        freeze        shirt       freeze
# 80          hurt        suffering    discomfort      running      running
# 81       citizen            local        native        guide        guide
# 82         white            black           red        apple        apple
# 83        pencil           eraser         ruler         baby         baby
# 84        square           circle      triangle     trousers     trousers
# 85   dining room          kitchen      bathroom        green        green
# 86         skirt            dress        jacket          pen          pen
# 87         apple             pear    strawberry        phone        phone
# 88           leg             head           arm        glass        glass
# 89         grape           orange     raspberry       potato    raspberry
# 90      climbing         swimming       cycling         face         face
# 91        eleven           twelve         three          May          May
# 92      football           tennis    basketball        water        water
# 93          rose            daisy          lily     computer     computer
# 94        market           bakery       butcher        bread       market
# 95          milk              tea        coffee         pink         pink
# 96           bus            train         plane        three        three
# 97       wedding            groom         bride     spinster     spinster
# 98           hot              big         heavy          sad          sad
# 99          give             sing          walk           go           go
# 100      careful        beautiful         awful        write        write
# 101         none         somebody           few         that         that
# 102           on               in            at         then           at
# 103      believe          receive         siege       friend      receive
# 104          row           column          cell         boat         boat
# 105         wave             lake         ocean     greeting         lake
# 106        eagle              bat      kangaroo   volleyball        eagle
# 107         drum           guitar          bass        shark        shark
# 108         back             head           leg      forward         back
# 109       summer             fall        spring         jump         jump
# 110       desert           forest      mountain      starter       forest
# 111       letter           number     character         poem       number
# 112        right          forward          left      correct      correct
# 113         ring         necklace         watch      calling      calling
# 114          tie           blazer         shirt         knob       blazer
# 115        train         training           gym       flower        train
# 116        train              car           bus          gym          gym
# 117          run          running           ran        house        house
# 118    beautiful             ugly          nice      trailer      trailer
# 119       butter            bread          milk    butterfly    butterfly
# 120        sleep         sleeping        sleepy       Tarzan       Tarzan
# 121          arm              leg          hand         army         army
# 122         bear            carry          bore          dog        carry
# 123         sing             song         music        sting        sting
# 124      several             many          lots          few         lots
# 125         sand           bikini           tan        grass          tan
# 126         game          gameboy          play          boy         game
# 127     labrador        chihuahua           pug       banana    chihuahua
# 128       mother           father      daughter          sun          sun
# 129          bus           banana     sunflower        ocean    sunflower
# 130          tan             tank      Tanzania          cup     Tanzania
# 131    Tanqueray           Bombay        Gordon      student      student
# 132          gun             dead           die         pony         pony
# 133        bacon             salt      pretzels        jelly     pretzels
# 134       yellow           cheese           sun        plant       yellow
# 135        woman              man          love        candy         love
# 136         blue           orange        yellow        spoon        spoon
# 137         face             nose         smile     facebook     facebook
# 138     in front           behind         below          cow        below
# 139        cloud           cloudy        clouds       cinema       cinema
# 140    sunflower         sunshine    sunglasses    challenge    challenge
# 141         rain         umbrella       thunder        happy     umbrella
# 142    chocolate            chips       cookies       dinner        chips
# 143         feel            smell           see          eye          see
# 144      western          fiction      thriller      theater     thriller
# 145         fear          concern        sorrow        opera        opera
# 146        mouth            teeth           eye          arm        teeth
# 147        death            grave       funeral          arm          arm
# 148     distress          sadness        sorrow        happy        happy
# 149     football           tennis      handball       summer       summer
# 150       summer           bikini          sand         snow       summer
# 151     magazine         brochure      notebook     computer     computer
# 152         gift             give        donate         take       donate
# 153         good           better          best          bad       better
# 154   manipulate            mango           man         show        mango
# 155          cat            tiger        jaguar     elephant          cat
# 156   Copenhagen        Amsterdam       Beijing       Norway   Copenhagen
# 157    apartment            house       cottage         lion         lion
# 158       Lyngby    Frederiksberg   Klampenborg          bun          bun
# 159          run            sleep         drink       bottle          run
# 160        table            chair           bed        study        study
# 161        drink         drinking         drink         sand     drinking
# 162          tea           coffee         cocoa       cancer       cancer
# 163        heart             lung        kidney     headache        heart
# 164      Denmark           Norway        Sweden      Germany      Denmark
# 165        sleep         sleeping         slept       school       school
# 166          fly           spider           ant         bird          ant
# 167       carrot           tomato      cucumber          car     cucumber
# 168          sun             rain       thunder        glass        glass
# 169          vin            vodka           gin        couch        couch
# 170         blue           orange           red        horse        horse
# 171     computer          gameboy      Nintendo          cat     Nintendo
# 172          bed           pillow         quilt       window       window
# 173       Sunday           Monday      Thursday          sun          sun
# 174       banana           orange         apple          run          run
# 175        pizza            pasta    mozzarella         show   mozzarella
# 176          run             walk         drive          cup        drive
# 177     Facebook        Instagram       YouTube        sleep        sleep
# 178         lamp              sun    flashlight        happy        happy
# 179          cat              dog         mouse          cry          cry
# 180          car              fly         train    butterfly    butterfly
# 181        uncle             aunt        cousin         fear         fear
# 182          DTU               KU           ITU        plant        plant
#
#              cov          dot              SVD              PCA       cosine
# 0          plane        plane              car            train          car
# 1         sister       sister          brother           sister         iron
# 2          couch        couch            couch            stool         door
# 3           tree         tree             tree             tree        clock
# 4         camera       camera           poster           poster       camera
# 5          meter        meter           height           weight        meter
# 6           worm         worm        cockroach             worm    cockroach
# 7          knife        knife          cereals             milk        knife
# 8        kitchen      kitchen            lunch            lunch      kitchen
# 9       baseball     baseball         baseball       basketball     strategy
# 10           net          net              net              net          net
# 11        cheese       cheese           shorts            shirt       cheese
# 12         money        money              bag              bag        money
# 13         plane        plane            truck              car        plane
# 14        coffee       coffee           coffee             soda        pasta
# 15          rain         rain             wind             wind      poverty
# 16   probability  probability      probability             math  environment
# 17    derivative   derivative           course       derivative     integral
# 18         class        class          student          student        class
# 19        pencil       pencil            brush            brush       duster
# 20        market       market           pencil           pencil       market
# 21      strategy     strategy           income           income     strategy
# 22         virus        virus         bacteria            virus        virus
# 23         disco        disco              bar              bar        disco
# 24    university   university           school           school     building
# 25      notebook     notebook            sheet            sheet      stapler
# 26       problem      problem          caution          caution      problem
# 27         knife        knife              gun              gun         care
# 28         price        price            price            price      receipt
# 29         lucky        lucky       optimistic            lucky        lucky
# 30           bag          bag            brown            green          bag
# 31         radio        radio       television       television     medicine
# 32   engineering  engineering          science      engineering     religion
# 33          shop         shop        cathedral        cathedral         shop
# 34     companion    companion           friend           friend        guest
# 35    psychology   psychology          anatomy       philosophy   psychology
# 36          fear         fear             fear             fear          bed
# 37       meeting      meeting        professor        professor       pepper
# 38        Turkey       Turkey          Denmark            Spain       Turkey
# 39           son          son         daughter            child       family
# 40       process      process             data             data         room
# 41          game         game             game             game      console
# 42      baseball     baseball              bat         baseball     baseball
# 43      follower     follower  air-conditioner  air-conditioner     follower
# 44         model        model             lead             lead    aluminium
# 45        column       column           column           column         boat
# 46           cut          cut             tear             tear          eye
# 47          axis         axis            pivot            pivot        sword
# 48         curve        curve            arrow            arrow        arrow
# 49           pay          pay              pay             good          pay
# 50       capital      capital             town             town      capital
# 51           can          can              jar              jar       manage
# 52           pub          pub           bistro           bistro       bistro
# 53      straight     straight             left             went     straight
# 54          fish         fish           salmon           salmon         fish
# 55            up           up            right            right      correct
# 56          pine         pine             palm             palm         pine
# 57       display      display            watch            watch        watch
# 58       Spanish      Spanish          Spanish          Spanish      Spanish
# 59           tie          tie           attach           attach       attach
# 60          bang         bang        wristband        wristband         bang
# 61         whale        whale            stamp            stamp        stamp
# 62        square       square           square           square        green
# 63          word         word             word             word         four
# 64        gossip       gossip           gossip           gossip        empty
# 65   information  information      information      information  information
# 66        detect       detect           notice           notice         hard
# 67        belief       belief         thoughts         thoughts     keyboard
# 68          goal         goal             goal             goal     continue
# 69          brow         brow              bed              eye         brow
# 70           fun          fun             joke            humor     counting
# 71         train        train       evaluation       evaluation        train
# 72         essay        essay            essay            essay      article
# 73         judge        judge      environment      environment        judge
# 74        circus       circus           circus              zoo         ring
# 75      forecast     forecast          predict          predict         chew
# 76        coffin       coffin           buried           buried        cheek
# 77       extinct      extinct          abolish          extinct      extinct
# 78         radio        radio        telephone        telephone          eat
# 79        freeze       freeze           freeze           freeze       freeze
# 80       running      running        suffering             hurt      running
# 81         local        local           native           native        guide
# 82         apple        apple            white            white        apple
# 83        pencil       pencil            ruler           eraser         baby
# 84        square       square           square           square     trousers
# 85      bathroom     bathroom      dining room      dining room        green
# 86         skirt        skirt            dress            skirt          pen
# 87         phone        phone            apple            apple        phone
# 88           arm          arm              leg              leg        glass
# 89        potato       potato           orange           orange    raspberry
# 90       cycling      cycling         climbing          cycling         face
# 91         three        three           eleven           eleven          May
# 92      football     football           tennis         football        water
# 93      computer     computer             rose             rose     computer
# 94        market       market           bakery           market       market
# 95        coffee       coffee              tea              tea         pink
# 96         plane        plane              bus              bus        three
# 97       wedding      wedding            groom            groom     spinster
# 98           big          big            heavy              big          sad
# 99          walk         walk             give             give           go
# 100        write        write        beautiful        beautiful        write
# 101          few          few             that             none         that
# 102           at           at               on               on           at
# 103      receive      receive          believe          believe      receive
# 104         cell         cell              row              row         boat
# 105     greeting     greeting            ocean             wave         lake
# 106        eagle        eagle            eagle            eagle        eagle
# 107        shark        shark           guitar             bass        shark
# 108      forward      forward              leg              leg         back
# 109         jump         jump           summer           summer         jump
# 110       forest       forest           forest           forest       forest
# 111       number       number             poem           letter       number
# 112      forward      forward          correct          correct      correct
# 113      calling      calling         necklace             ring      calling
# 114         knob         knob            shirt              tie       blazer
# 115        train        train            train            train        train
# 116        train        train            train            train          gym
# 117          run          run              run              run        house
# 118      trailer      trailer        beautiful        beautiful      trailer
# 119       butter       butter             milk             milk    butterfly
# 120        sleep        sleep           sleepy           sleepy       Tarzan
# 121         army         army             army              arm         army
# 122        carry        carry            carry            carry        carry
# 123        sting        sting            music            music        sting
# 124          few          few          several          several         lots
# 125          tan          tan            grass             sand          tan
# 126         game         game          gameboy             play         game
# 127       banana       banana        chihuahua              pug    chihuahua
# 128          sun          sun         daughter         daughter          sun
# 129          bus          bus              bus              bus    sunflower
# 130         tank         tank         Tanzania         Tanzania     Tanzania
# 131      student      student        Tanqueray        Tanqueray      student
# 132          gun          gun              die             dead         pony
# 133         salt         salt             salt         pretzels     pretzels
# 134       cheese       cheese              sun              sun       yellow
# 135         love         love            woman             love         love
# 136       yellow       yellow             blue             blue        spoon
# 137     facebook     facebook             face             face     facebook
# 138          cow          cow         in front         in front        below
# 139        cloud        cloud            cloud            cloud       cinema
# 140    challenge    challenge        sunflower        sunflower    challenge
# 141     umbrella     umbrella         umbrella         umbrella     umbrella
# 142        chips        chips          cookies          cookies        chips
# 143        smell        smell              see            smell          see
# 144      fiction      fiction         thriller         thriller     thriller
# 145        opera        opera          concern             fear        opera
# 146        teeth        teeth              eye              eye        teeth
# 147          arm          arm          funeral            death          arm
# 148        happy        happy           sorrow           sorrow        happy
# 149     football     football         football         football       summer
# 150         snow         snow           summer           summer       summer
# 151     computer     computer         magazine         magazine     computer
# 152         take         take             gift             gift       donate
# 153       better       better           better           better       better
# 154         show         show       manipulate       manipulate        mango
# 155          cat          cat         elephant         elephant          cat
# 156      Beijing      Beijing          Beijing        Amsterdam   Copenhagen
# 157         lion         lion        apartment        apartment         lion
# 158          bun          bun           Lyngby           Lyngby          bun
# 159          run          run           bottle              run          run
# 160        study        study            table            table        study
# 161        drink        drink            drink            drink     drinking
# 162       coffee       coffee           coffee            cocoa       cancer
# 163        heart        heart           kidney            heart        heart
# 164      Denmark      Denmark          Denmark           Norway      Denmark
# 165        sleep        sleep           school         sleeping       school
# 166          fly          fly              ant           spider          ant
# 167          car          car           carrot           carrot     cucumber
# 168         rain         rain             rain             rain        glass
# 169        couch        couch            couch            vodka        couch
# 170        horse        horse             blue             blue        horse
# 171          cat          cat         computer         computer     Nintendo
# 172       window       window           pillow              bed       window
# 173          sun          sun           Sunday           Sunday          sun
# 174          run          run            apple           orange          run
# 175         show         show       mozzarella            pasta   mozzarella
# 176        drive        drive             walk             walk        drive
# 177        sleep        sleep         Facebook         Facebook        sleep
# 178         lamp         lamp       flashlight       flashlight        happy
# 179          cat          cat              cat              cat          cry
# 180        train        train            train              fly    butterfly
# 181       cousin       cousin            uncle             aunt         fear
# 182        plant        plant              DTU              DTU        plant

# %% [markdown]
# ## Using sentences

# %%
corrcoef_outliers, cov_outliers, dot_outliers, cosine_outliers, svd_outliers, pca_outliers = [], [], [], [], [], []
for i in range(len(four_words_csv)): 
    vectors = np.zeros((4,1024))
    word0 = four_words_csv[i][0].split()[0]
    word1 = four_words_csv[i][1].split()[0]
    word2 = four_words_csv[i][2].split()[0]
    word3 = four_words_csv[i][3].split()[0]
    
    vectors[0,:] = bc.encode(['How similar is '+word0+' to '+word1+' , '+word2+' and '+word3])
    vectors[1,:] = bc.encode(['How similar is '+word1+' to '+word0+' , '+word2+' and '+word3])
    vectors[2,:] = bc.encode(['How similar is '+word2+' to '+word0+' , '+word1+' and '+word3])
    vectors[3,:] = bc.encode(['How similar is '+word3+' to '+word0+' , '+word1+' and '+word2])
    
    
    R = np.corrcoef(vectors)
    indices = np.argsort(R.sum(axis=0))
    outlier = four_words_csv[i][indices[0]]
    corrcoef_outliers.append(outlier)

    C = np.cov(vectors)
    indices = np.argsort(C.sum(axis=0))
    outlier = four_words_csv[i][indices[0]]
    cov_outliers.append(outlier)

    D = np.dot(vectors, vectors.T)
    indices = np.argsort(D.sum(axis=0))
    outlier = four_words_csv[i][indices[0]]
    dot_outliers.append(outlier)
    
    CO = np.dot(vectors, vectors.T)
    square_mag = np.diag(CO)
    inv_square_mag = 1 / square_mag
    inv_square_mag[np.isinf(inv_square_mag)] = 0
    inv_mag = np.sqrt(inv_square_mag)
    cosine = CO * inv_mag
    cosine = cosine.T * inv_mag
    indices = np.argsort(cosine.sum(axis=0))
    outlier = four_words_csv[i][indices[0]]
    cosine_outliers.append(outlier)
    
    
    vecs = np.transpose(vectors)
    MeanVector = np.mean(vecs, axis = 1)[:,np.newaxis]
    vecs = np.concatenate((vecs,MeanVector), axis = 1)
    
    # SVD
    U, s, Vh = np.linalg.svd(vecs,full_matrices=False)
    Dist = np.zeros(4)

    for j in range(4):
        Dist[j] = np.linalg.norm(U[4,0]-U[j,0])+np.linalg.norm(U[4,1]-U[j,1])
    outlier = four_words_csv[i][np.where(Dist == max(Dist))[0][0]]
    svd_outliers.append(outlier)
    
    
    # PCA
    pca_vecs = PCA(n_components=2, svd_solver = 'arpack')
    X_pca_vecs = pca_vecs.fit_transform(vecs) # Calculate PCA of vector

    Dist_pca_vecs = np.zeros(4) # Calculate distance 
    for j in range(4):
        Dist_pca_vecs[j] = np.linalg.norm(X_pca_vecs[4,0]-X_pca_vecs[j,0])+np.linalg.norm(X_pca_vecs[4,1]-X_pca_vecs[j,1])
    outlier = four_words_csv[i][np.where(Dist_pca_vecs == max(Dist_pca_vecs))[0][0]]
    pca_outliers.append(outlier)
    
    print('Progress', i)
# Out:
# Progress 0
# Progress 1
# Progress 2
# Progress 3
# Progress 4
# Progress 5
# Progress 6
# Progress 7
# Progress 8
# Progress 9
# Progress 10
# Progress 11
# Progress 12
# Progress 13
# Progress 14
# Progress 15
# Progress 16
# Progress 17
# Progress 18
# Progress 19
# Progress 20
# Progress 21
# Progress 22
# Progress 23
# Progress 24
# Progress 25
# Progress 26
# Progress 27
# Progress 28
# Progress 29
# Progress 30
# Progress 31
# Progress 32
# Progress 33
# Progress 34
# Progress 35
# Progress 36
# Progress 37
# Progress 38
# Progress 39
# Progress 40
# Progress 41
# Progress 42
# Progress 43
# Progress 44
# Progress 45
# Progress 46
# Progress 47
# Progress 48
# Progress 49
# Progress 50
# Progress 51
# Progress 52
# Progress 53
# Progress 54
# Progress 55
# Progress 56
# Progress 57
# Progress 58
# Progress 59
# Progress 60
# Progress 61
# Progress 62
# Progress 63
# Progress 64
# Progress 65
# Progress 66
# Progress 67
# Progress 68
# Progress 69
# Progress 70
# Progress 71
# Progress 72
# Progress 73
# Progress 74
# Progress 75
# Progress 76
# Progress 77
# Progress 78
# Progress 79
# Progress 80
# Progress 81
# Progress 82
# Progress 83
# Progress 84
# Progress 85
# Progress 86
# Progress 87
# Progress 88
# Progress 89
# Progress 90
# Progress 91
# Progress 92
# Progress 93
# Progress 94
# Progress 95
# Progress 96
# Progress 97
# Progress 98
# Progress 99
# Progress 100
# Progress 101
# Progress 102
# Progress 103
# Progress 104
# Progress 105
# Progress 106
# Progress 107
# Progress 108
# Progress 109
# Progress 110
# Progress 111
# Progress 112
# Progress 113
# Progress 114
# Progress 115
# Progress 116
# Progress 117
# Progress 118
# Progress 119
# Progress 120
# Progress 121
# Progress 122
# Progress 123
# Progress 124
# Progress 125
# Progress 126
# Progress 127
# Progress 128
# Progress 129
# Progress 130
# Progress 131
# Progress 132
# Progress 133
# Progress 134
# Progress 135
# Progress 136
# Progress 137
# Progress 138
# Progress 139
# Progress 140
# Progress 141
# Progress 142
# Progress 143
# Progress 144
# Progress 145
# Progress 146
# Progress 147
# Progress 148
# Progress 149
# Progress 150
# Progress 151
# Progress 152
# Progress 153
# Progress 154
# Progress 155
# Progress 156
# Progress 157
# Progress 158
# Progress 159
# Progress 160
# Progress 161
# Progress 162
# Progress 163
# Progress 164
# Progress 165
# Progress 166
# Progress 167
# Progress 168
# Progress 169
# Progress 170
# Progress 171
# Progress 172
# Progress 173
# Progress 174
# Progress 175
# Progress 176
# Progress 177
# Progress 178
# Progress 179
# Progress 180
# Progress 181
# Progress 182

# %%
sum_corr = 0
for i in range(len(four_words_csv)):
    if four_words_csv[i][3] == corrcoef_outliers[i]:
        sum_corr += 1
    
print('Outlier detection using correlation coefficients', sum_corr/len(four_words_csv))

sum_cov = 0
for i in range(len(four_words_csv)):
    if four_words_csv[i][3] == cov_outliers[i]:
        sum_cov += 1
    
print('Outlier detection using covarians', sum_cov/len(four_words_csv))

sum_dot = 0
for i in range(len(four_words_csv)):
    if four_words_csv[i][3] == dot_outliers[i]:
        sum_dot += 1
    
print('Outlier detection using dot', sum_dot/len(four_words_csv))

sum_svd = 0
for i in range(len(four_words_csv)):
    if four_words_csv[i][3] == svd_outliers[i]:
        sum_svd += 1
    
print('Outlier detection using SVD', sum_svd/len(four_words_csv))

sum_pca = 0
for i in range(len(four_words_csv)):
    if four_words_csv[i][3] == pca_outliers[i]:
        sum_pca += 1
    
print('Outlier detection using PCA', sum_pca/len(four_words_csv))

sum_cosine = 0
for i in range(len(four_words_csv)):
    if four_words_csv[i][3] == cosine_outliers[i]:
        sum_cosine += 1
    
print('Outlier detection using cosine', sum_cosine/len(four_words_csv))
# Out:
# Outlier detection using correlation coefficients 0.825136612021858
# Outlier detection using covarians 0.2677595628415301
# Outlier detection using dot 0.2677595628415301
# Outlier detection using SVD 0.08743169398907104
# Outlier detection using PCA 0.01639344262295082
# Outlier detection using cosine 0.825136612021858

# %%
corrcoef_outliers, cov_outliers, dot_outliers, cosine_outliers, svd_outliers, pca_outliers = [], [], [], [], [], []
for i in range(len(four_words_csv)): 
    vectors = np.zeros((4,1024))
    word0 = four_words_csv[i][0].split()[0]
    word1 = four_words_csv[i][1].split()[0]
    word2 = four_words_csv[i][2].split()[0]
    word3 = four_words_csv[i][3].split()[0]
    
    vectors[0,:] = bc.encode(['Does '+word0+' match with '+word1+' , '+word2+' and '+word3])
    vectors[1,:] = bc.encode(['Does '+word1+' match with '+word0+' , '+word2+' and '+word3])
    vectors[2,:] = bc.encode(['Does '+word2+' match with '+word0+' , '+word1+' and '+word3])
    vectors[3,:] = bc.encode(['Does '+word3+' match with '+word0+' , '+word1+' and '+word2])
    
    
    R = np.corrcoef(vectors)
    indices = np.argsort(R.sum(axis=0))
    outlier = four_words_csv[i][indices[0]]
    corrcoef_outliers.append(outlier)

    C = np.cov(vectors)
    indices = np.argsort(C.sum(axis=0))
    outlier = four_words_csv[i][indices[0]]
    cov_outliers.append(outlier)

    D = np.dot(vectors, vectors.T)
    indices = np.argsort(D.sum(axis=0))
    outlier = four_words_csv[i][indices[0]]
    dot_outliers.append(outlier)
    
    CO = np.dot(vectors, vectors.T)
    square_mag = np.diag(CO)
    inv_square_mag = 1 / square_mag
    inv_square_mag[np.isinf(inv_square_mag)] = 0
    inv_mag = np.sqrt(inv_square_mag)
    cosine = CO * inv_mag
    cosine = cosine.T * inv_mag
    indices = np.argsort(cosine.sum(axis=0))
    outlier = four_words_csv[i][indices[0]]
    cosine_outliers.append(outlier)
    
    
    vecs = np.transpose(vectors)
    MeanVector = np.mean(vecs, axis = 1)[:,np.newaxis]
    vecs = np.concatenate((vecs,MeanVector), axis = 1)
    
    # SVD
    U, s, Vh = np.linalg.svd(vecs,full_matrices=False)
    Dist = np.zeros(4)

    for j in range(4):
        Dist[j] = np.linalg.norm(U[4,0]-U[j,0])+np.linalg.norm(U[4,1]-U[j,1])
    outlier = four_words_csv[i][np.where(Dist == max(Dist))[0][0]]
    svd_outliers.append(outlier)
    
    
    # PCA
    pca_vecs = PCA(n_components=2, svd_solver = 'arpack')
    X_pca_vecs = pca_vecs.fit_transform(vecs) # Calculate PCA of vector

    Dist_pca_vecs = np.zeros(4) # Calculate distance 
    for j in range(4):
        Dist_pca_vecs[j] = np.linalg.norm(X_pca_vecs[4,0]-X_pca_vecs[j,0])+np.linalg.norm(X_pca_vecs[4,1]-X_pca_vecs[j,1])
    outlier = four_words_csv[i][np.where(Dist_pca_vecs == max(Dist_pca_vecs))[0][0]]
    pca_outliers.append(outlier)
    
    print('Progress', i)
# Out:
# Progress 0
# Progress 1
# Progress 2
# Progress 3
# Progress 4
# Progress 5
# Progress 6
# Progress 7
# Progress 8
# Progress 9
# Progress 10
# Progress 11
# Progress 12
# Progress 13
# Progress 14
# Progress 15
# Progress 16
# Progress 17
# Progress 18
# Progress 19
# Progress 20
# Progress 21
# Progress 22
# Progress 23
# Progress 24
# Progress 25
# Progress 26
# Progress 27
# Progress 28
# Progress 29
# Progress 30
# Progress 31
# Progress 32
# Progress 33
# Progress 34
# Progress 35
# Progress 36
# Progress 37
# Progress 38
# Progress 39
# Progress 40
# Progress 41
# Progress 42
# Progress 43
# Progress 44
# Progress 45
# Progress 46
# Progress 47
# Progress 48
# Progress 49
# Progress 50
# Progress 51
# Progress 52
# Progress 53
# Progress 54
# Progress 55
# Progress 56
# Progress 57
# Progress 58
# Progress 59
# Progress 60
# Progress 61
# Progress 62
# Progress 63
# Progress 64
# Progress 65
# Progress 66
# Progress 67
# Progress 68
# Progress 69
# Progress 70
# Progress 71
# Progress 72
# Progress 73
# Progress 74
# Progress 75
# Progress 76
# Progress 77
# Progress 78
# Progress 79
# Progress 80
# Progress 81
# Progress 82
# Progress 83
# Progress 84
# Progress 85
# Progress 86
# Progress 87
# Progress 88
# Progress 89
# Progress 90
# Progress 91
# Progress 92
# Progress 93
# Progress 94
# Progress 95
# Progress 96
# Progress 97
# Progress 98
# Progress 99
# Progress 100
# Progress 101
# Progress 102
# Progress 103
# Progress 104
# Progress 105
# Progress 106
# Progress 107
# Progress 108
# Progress 109
# Progress 110
# Progress 111
# Progress 112
# Progress 113
# Progress 114
# Progress 115
# Progress 116
# Progress 117
# Progress 118
# Progress 119
# Progress 120
# Progress 121
# Progress 122
# Progress 123
# Progress 124
# Progress 125
# Progress 126
# Progress 127
# Progress 128
# Progress 129
# Progress 130
# Progress 131
# Progress 132
# Progress 133
# Progress 134
# Progress 135
# Progress 136
# Progress 137
# Progress 138
# Progress 139
# Progress 140
# Progress 141
# Progress 142
# Progress 143
# Progress 144
# Progress 145
# Progress 146
# Progress 147
# Progress 148
# Progress 149
# Progress 150
# Progress 151
# Progress 152
# Progress 153
# Progress 154
# Progress 155
# Progress 156
# Progress 157
# Progress 158
# Progress 159
# Progress 160
# Progress 161
# Progress 162
# Progress 163
# Progress 164
# Progress 165
# Progress 166
# Progress 167
# Progress 168
# Progress 169
# Progress 170
# Progress 171
# Progress 172
# Progress 173
# Progress 174
# Progress 175
# Progress 176
# Progress 177
# Progress 178
# Progress 179
# Progress 180
# Progress 181
# Progress 182

# %%
sum_corr = 0
for i in range(len(four_words_csv)):
    if four_words_csv[i][3] == corrcoef_outliers[i]:
        sum_corr += 1
    
print('Outlier detection using correlation coefficients', sum_corr/len(four_words_csv))

sum_cov = 0
for i in range(len(four_words_csv)):
    if four_words_csv[i][3] == cov_outliers[i]:
        sum_cov += 1
    
print('Outlier detection using covarians', sum_cov/len(four_words_csv))

sum_dot = 0
for i in range(len(four_words_csv)):
    if four_words_csv[i][3] == dot_outliers[i]:
        sum_dot += 1
    
print('Outlier detection using dot', sum_dot/len(four_words_csv))

sum_svd = 0
for i in range(len(four_words_csv)):
    if four_words_csv[i][3] == svd_outliers[i]:
        sum_svd += 1
    
print('Outlier detection using SVD', sum_svd/len(four_words_csv))

sum_pca = 0
for i in range(len(four_words_csv)):
    if four_words_csv[i][3] == pca_outliers[i]:
        sum_pca += 1
    
print('Outlier detection using PCA', sum_pca/len(four_words_csv))

sum_cosine = 0
for i in range(len(four_words_csv)):
    if four_words_csv[i][3] == cosine_outliers[i]:
        sum_cosine += 1
    
print('Outlier detection using cosine', sum_cosine/len(four_words_csv))
# Out:
# Outlier detection using correlation coefficients 0.7377049180327869
# Outlier detection using covarians 0.5846994535519126
# Outlier detection using dot 0.5846994535519126
# Outlier detection using SVD 0.09289617486338798
# Outlier detection using PCA 0.12021857923497267
# Outlier detection using cosine 0.7377049180327869

# %%
corrcoef_outliers, cov_outliers, dot_outliers, cosine_outliers, svd_outliers, pca_outliers = [], [], [], [], [], []
for i in range(len(four_words_csv)): 
    vectors = np.zeros((4,1024))
    word0 = four_words_csv[i][0].split()[0]
    word1 = four_words_csv[i][1].split()[0]
    word2 = four_words_csv[i][2].split()[0]
    word3 = four_words_csv[i][3].split()[0]
    
    vectors[0,:] = np.mean(bc.encode(['How similar is '+word0+' to '+word1])+bc.encode(['How similar is '+word0+' to '+word2])+bc.encode(['How similar is '+word0+' to '+word3]), axis=0)                       
    vectors[1,:] = np.mean(bc.encode(['How similar is '+word1+' to '+word0])+bc.encode(['How similar is '+word1+' to '+word2])+bc.encode(['How similar is '+word1+' to '+word3]), axis=0)
    vectors[2,:] = np.mean(bc.encode(['How similar is '+word2+' to '+word0])+bc.encode(['How similar is '+word2+' to '+word1])+bc.encode(['How similar is '+word2+' to '+word3]), axis=0)
    vectors[3,:] = np.mean(bc.encode(['How similar is '+word3+' to '+word0])+bc.encode(['How similar is '+word3+' to '+word1])+bc.encode(['How similar is '+word3+' to '+word2]), axis=0)
    
    
    R = np.corrcoef(vectors)
    indices = np.argsort(R.sum(axis=0))
    outlier = four_words_csv[i][indices[0]]
    corrcoef_outliers.append(outlier)

    C = np.cov(vectors)
    indices = np.argsort(C.sum(axis=0))
    outlier = four_words_csv[i][indices[0]]
    cov_outliers.append(outlier)

    D = np.dot(vectors, vectors.T)
    indices = np.argsort(D.sum(axis=0))
    outlier = four_words_csv[i][indices[0]]
    dot_outliers.append(outlier)
    
    CO = np.dot(vectors, vectors.T)
    square_mag = np.diag(CO)
    inv_square_mag = 1 / square_mag
    inv_square_mag[np.isinf(inv_square_mag)] = 0
    inv_mag = np.sqrt(inv_square_mag)
    cosine = CO * inv_mag
    cosine = cosine.T * inv_mag
    indices = np.argsort(cosine.sum(axis=0))
    outlier = four_words_csv[i][indices[0]]
    cosine_outliers.append(outlier)
    
    
    vecs = np.transpose(vectors)
    MeanVector = np.mean(vecs, axis = 1)[:,np.newaxis]
    vecs = np.concatenate((vecs,MeanVector), axis = 1)
    
    # SVD
    U, s, Vh = np.linalg.svd(vecs,full_matrices=False)
    Dist = np.zeros(4)

    for j in range(4):
        Dist[j] = np.linalg.norm(U[4,0]-U[j,0])+np.linalg.norm(U[4,1]-U[j,1])
    outlier = four_words_csv[i][np.where(Dist == max(Dist))[0][0]]
    svd_outliers.append(outlier)
    
    
    # PCA
    pca_vecs = PCA(n_components=2, svd_solver = 'arpack')
    X_pca_vecs = pca_vecs.fit_transform(vecs) # Calculate PCA of vector

    Dist_pca_vecs = np.zeros(4) # Calculate distance 
    for j in range(4):
        Dist_pca_vecs[j] = np.linalg.norm(X_pca_vecs[4,0]-X_pca_vecs[j,0])+np.linalg.norm(X_pca_vecs[4,1]-X_pca_vecs[j,1])
    outlier = four_words_csv[i][np.where(Dist_pca_vecs == max(Dist_pca_vecs))[0][0]]
    pca_outliers.append(outlier)
    
    print('Progress', i)
# Out:
# Progress 0
# Progress 1
# Progress 2
# Progress 3
# Progress 4
# Progress 5
# Progress 6
# Progress 7
# Progress 8
# Progress 9
# Progress 10
# Progress 11
# Progress 12
# Progress 13
# Progress 14
# Progress 15
# Progress 16
# Progress 17
# Progress 18
# Progress 19
# Progress 20
# Progress 21
# Progress 22
# Progress 23
# Progress 24
# Progress 25
# Progress 26
# Progress 27
# Progress 28
# Progress 29
# Progress 30
# Progress 31
# Progress 32
# Progress 33
# Progress 34
# Progress 35
# Progress 36
# Progress 37
# Progress 38
# Progress 39
# Progress 40
# Progress 41
# Progress 42
# Progress 43
# Progress 44
# Progress 45
# Progress 46
# Progress 47
# Progress 48
# Progress 49
# Progress 50
# Progress 51
# Progress 52
# Progress 53
# Progress 54
# Progress 55
# Progress 56
# Progress 57
# Progress 58
# Progress 59
# Progress 60
# Progress 61
# Progress 62
# Progress 63
# Progress 64
# Progress 65
# Progress 66
# Progress 67
# Progress 68
# Progress 69
# Progress 70
# Progress 71
# Progress 72
# Progress 73
# Progress 74
# Progress 75
# Progress 76
# Progress 77
# Progress 78
# Progress 79
# Progress 80
# Progress 81
# Progress 82
# Progress 83
# Progress 84
# Progress 85
# Progress 86
# Progress 87
# Progress 88
# Progress 89
# Progress 90
# Progress 91
# Progress 92
# Progress 93
# Progress 94
# Progress 95
# Progress 96
# Progress 97
# Progress 98
# Progress 99
# Progress 100
# Progress 101
# Progress 102
# Progress 103
# Progress 104
# Progress 105
# Progress 106
# Progress 107
# Progress 108
# Progress 109
# Progress 110
# Progress 111
# Progress 112
# Progress 113
# Progress 114
# Progress 115
# Progress 116
# Progress 117
# Progress 118
# Progress 119
# Progress 120
# Progress 121
# Progress 122
# Progress 123
# Progress 124
# Progress 125
# Progress 126
# Progress 127
# Progress 128
# Progress 129
# Progress 130
# Progress 131
# Progress 132
# Progress 133
# Progress 134
# Progress 135
# Progress 136
# Progress 137
# Progress 138
# Progress 139
# Progress 140
# Progress 141
# Progress 142
# Progress 143
# Progress 144
# Progress 145
# Progress 146
# Progress 147
# Progress 148
# Progress 149
# Progress 150
# Progress 151
# Progress 152
# Progress 153
# Progress 154
# Progress 155
# Progress 156
# Progress 157
# Progress 158
# Progress 159
# Progress 160
# Progress 161
# Progress 162
# Progress 163
# Progress 164
# Progress 165
# Progress 166
# Progress 167
# Progress 168
# Progress 169
# Progress 170
# Progress 171
# Progress 172
# Progress 173
# Progress 174
# Progress 175
# Progress 176
# Progress 177
# Progress 178
# Progress 179
# Progress 180
# Progress 181
# Progress 182

# %%
sum_corr = 0
for i in range(len(four_words_csv)):
    if four_words_csv[i][3] == corrcoef_outliers[i]:
        sum_corr += 1
    
print('Outlier detection using correlation coefficients', sum_corr/len(four_words_csv))

sum_cov = 0
for i in range(len(four_words_csv)):
    if four_words_csv[i][3] == cov_outliers[i]:
        sum_cov += 1
    
print('Outlier detection using covarians', sum_cov/len(four_words_csv))

sum_dot = 0
for i in range(len(four_words_csv)):
    if four_words_csv[i][3] == dot_outliers[i]:
        sum_dot += 1
    
print('Outlier detection using dot', sum_dot/len(four_words_csv))

sum_svd = 0
for i in range(len(four_words_csv)):
    if four_words_csv[i][3] == svd_outliers[i]:
        sum_svd += 1
    
print('Outlier detection using SVD', sum_svd/len(four_words_csv))

sum_pca = 0
for i in range(len(four_words_csv)):
    if four_words_csv[i][3] == pca_outliers[i]:
        sum_pca += 1
    
print('Outlier detection using PCA', sum_pca/len(four_words_csv))

sum_cosine = 0
for i in range(len(four_words_csv)):
    if four_words_csv[i][3] == cosine_outliers[i]:
        sum_cosine += 1
    
print('Outlier detection using cosine', sum_cosine/len(four_words_csv))
# Out:
# Outlier detection using correlation coefficients 0.6994535519125683
# Outlier detection using covarians 0.09836065573770492
# Outlier detection using dot 0.09836065573770492
# Outlier detection using SVD 0.03825136612021858
# Outlier detection using PCA 0.00546448087431694
# Outlier detection using cosine 0.6994535519125683
